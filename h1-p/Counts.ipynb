# %% [markdown]
# # Fetch NGram Counts

# %%
import pandas as pd

df = pd.read_csv('gene.ngrams', sep=' ', names=['Count', 'NGram', 'One', 'Two', 'Three'])

# %%
df
# Out:
#      Count   NGram     One     Two   Three
# 0    41072  1-GRAM  I-GENE     NaN     NaN
# 1   345128  1-GRAM       O     NaN     NaN
# 2    24435  2-GRAM  I-GENE  I-GENE     NaN
# 3    15888  2-GRAM       O  I-GENE     NaN
# 4    16624  2-GRAM  I-GENE       O     NaN
# 5    13783  2-GRAM       O    STOP     NaN
# 6       13  2-GRAM  I-GENE    STOP     NaN
# 7    13047  2-GRAM       *       O     NaN
# 8   315457  2-GRAM       O       O     NaN
# 9      749  2-GRAM       *  I-GENE     NaN
# 10   13796  2-GRAM       *       *     NaN
# 11     749  3-GRAM       *       *  I-GENE
# 12   11320  3-GRAM  I-GENE       O       O
# 13    9622  3-GRAM  I-GENE  I-GENE       O
# 14  291686  3-GRAM       O       O       O
# 15       1  3-GRAM       O  I-GENE    STOP
# 16   12451  3-GRAM       *       O       O
# 17    3491  3-GRAM  I-GENE       O  I-GENE
# 18      11  3-GRAM  I-GENE  I-GENE    STOP
# 19   14802  3-GRAM  I-GENE  I-GENE  I-GENE
# 20       3  3-GRAM       *       O    STOP
# 21     296  3-GRAM       *  I-GENE       O
# 22   11967  3-GRAM       O       O    STOP
# 23    6706  3-GRAM       O  I-GENE       O
# 24    9181  3-GRAM       O  I-GENE  I-GENE
# 25     452  3-GRAM       *  I-GENE  I-GENE
# 26    1813  3-GRAM  I-GENE       O    STOP
# 27   13047  3-GRAM       *       *       O
# 28       1  3-GRAM       *  I-GENE    STOP
# 29   11804  3-GRAM       O       O  I-GENE
# 30     593  3-GRAM       *       O  I-GENE

# %% [markdown]
# # Unigrams

# %%
counts = {}

for tag, count in df[df['NGram'] == '1-GRAM'][['One', 'Count']].values:
    counts[tag] = count

# %% [markdown]
# # P(x|y)

# %%
with open('gene.counts', 'r') as f:
    lines = f.readlines()

# %%
lines
# Out:
# ['1 WORDTAG O mind\n',
#  '20 WORDTAG O resting\n',
#  '1 WORDTAG I-GENE SOX\n',
#  '2 WORDTAG I-GENE holoenzyme\n',
#  '2 WORDTAG I-GENE hydrolase\n',
#  '2 WORDTAG I-GENE barley\n',
#  '2 WORDTAG O glottic\n',
#  '1 WORDTAG O Palindromic\n',
#  '1 WORDTAG I-GENE amk\n',
#  '1 WORDTAG I-GENE opsin\n',
#  '1 WORDTAG O RLM\n',
#  '1 WORDTAG O nonautoimmune\n',
#  '1 WORDTAG O d10\n',
#  '1 WORDTAG O phantoms\n',
#  '18 WORDTAG O event\n',
#  '4 WORDTAG I-GENE member\n',
#  '1 WORDTAG O DMF\n',
#  '2 WORDTAG I-GENE lyn\n',
#  '1 WORDTAG I-GENE GAF\n',
#  '1 WORDTAG O unknowingly\n',
#  '110 WORDTAG O infection\n',
#  '1 WORDTAG I-GENE IRDelta960\n',
#  '4 WORDTAG O autonomic\n',
#  '1 WORDTAG O Healthcare\n',
#  '2 WORDTAG I-GENE tract\n',
#  '1 WORDTAG I-GENE L15\n',
#  '3 WORDTAG O porous\n',
#  '2 WORDTAG I-GENE CAB\n',
#  '7 WORDTAG O description\n',
#  '17 WORDTAG O 82\n',
#  '2 WORDTAG O younger\n',
#  '4 WORDTAG O favorable\n',
#  '1 WORDTAG O Calibration\n',
#  '1 WORDTAG I-GENE germanica\n',
#  '1 WORDTAG O 16T\n',
#  '1 WORDTAG O pHBK280\n',
#  '3 WORDTAG O Diet\n',
#  '1 WORDTAG I-GENE UEV1A\n',
#  '392 WORDTAG O human\n',
#  '2 WORDTAG O STG\n',
#  '1 WORDTAG O Delta102\n',
#  '1 WORDTAG O 3ASubE\n',
#  '2 WORDTAG O cow\n',
#  '1 WORDTAG O opacities\n',
#  '1 WORDTAG O Testar\n',
#  '5 WORDTAG O Prevention\n',
#  '1 WORDTAG O Complementary\n',
#  '1 WORDTAG O imipenam\n',
#  '1 WORDTAG O 41B\n',
#  '1 WORDTAG I-GENE PNA\n',
#  '1 WORDTAG O willful\n',
#  '3 WORDTAG O linoleic\n',
#  '1 WORDTAG O UC\n',
#  '1 WORDTAG O R254G\n',
#  '1 WORDTAG O haemodilution\n',
#  '20 WORDTAG O reduce\n',
#  '1 WORDTAG O Du\n',
#  '1 WORDTAG O lingual\n',
#  '2 WORDTAG O STD\n',
#  '31 WORDTAG I-GENE Raf\n',
#  '16 WORDTAG O Transient\n',
#  '2 WORDTAG O oropharyngeal\n',
#  '8 WORDTAG I-GENE mos\n',
#  '1 WORDTAG O Laboratoires\n',
#  '1 WORDTAG O remyelination\n',
#  '3 WORDTAG I-GENE FKBP\n',
#  '2 WORDTAG O estrogenic\n',
#  '4 WORDTAG I-GENE p110\n',
#  '1 WORDTAG O Kinase\n',
#  '1 WORDTAG O K241\n',
#  '1 WORDTAG O kink\n',
#  '1 WORDTAG O carbonaceous\n',
#  '1 WORDTAG I-GENE nidogen\n',
#  '2 WORDTAG I-GENE Cys\n',
#  '7 WORDTAG O run\n',
#  '1 WORDTAG O hypergeometric\n',
#  '1 WORDTAG I-GENE cgs1\n',
#  '1 WORDTAG O GBV\n',
#  '1 WORDTAG O 727\n',
#  '2 WORDTAG O Urine\n',
#  '3 WORDTAG O 327\n',
#  '1 WORDTAG O bocurarine\n',
#  '1 WORDTAG O hads\n',
#  '1 WORDTAG O synthetase\n',
#  '1 WORDTAG O ALP\n',
#  '3 WORDTAG I-GENE quinone\n',
#  '1 WORDTAG I-GENE PWM\n',
#  '1 WORDTAG O mammal\n',
#  '2 WORDTAG O pentagastrin\n',
#  '2 WORDTAG O deteriorated\n',
#  '1 WORDTAG O ZIC\n',
#  '1 WORDTAG O amikacin\n',
#  '1 WORDTAG I-GENE MPF\n',
#  '1 WORDTAG O neurohypophysial\n',
#  '2 WORDTAG O pyrophosphate\n',
#  '6 WORDTAG O started\n',
#  '1 WORDTAG O pallid\n',
#  '1 WORDTAG I-GENE exocrine\n',
#  '2 WORDTAG I-GENE NFI\n',
#  '2 WORDTAG O N22\n',
#  '1 WORDTAG O Viable\n',
#  '1 WORDTAG I-GENE NifL\n',
#  '2 WORDTAG O gammaherpesviruses\n',
#  '378 WORDTAG O during\n',
#  '2 WORDTAG O AmB\n',
#  '2 WORDTAG O 592\n',
#  '1 WORDTAG O Disorders\n',
#  '1 WORDTAG O locust\n',
#  '35 WORDTAG O still\n',
#  '1 WORDTAG O 797\n',
#  '1 WORDTAG O localizations\n',
#  '11 WORDTAG O evolutionarily\n',
#  '1 WORDTAG O RRMS\n',
#  '3 WORDTAG I-GENE DBH\n',
#  '1 WORDTAG I-GENE pCAD142\n',
#  '3 WORDTAG I-GENE nifV\n',
#  '2377 WORDTAG O by\n',
#  '4 WORDTAG O tolerant\n',
#  '1 WORDTAG O Alkoxymetgyl\n',
#  '1 WORDTAG O TX\n',
#  '1 WORDTAG O negatives\n',
#  '1 WORDTAG I-GENE 26\n',
#  '4 WORDTAG I-GENE outer\n',
#  '11 WORDTAG O tone\n',
#  '1 WORDTAG I-GENE gluten\n',
#  '2 WORDTAG O Clones\n',
#  '1 WORDTAG O ABK\n',
#  '1 WORDTAG O react\n',
#  '1 WORDTAG O palm\n',
#  '1 WORDTAG O FI120\n',
#  '3 WORDTAG O excitation\n',
#  '1 WORDTAG O IRP\n',
#  '6 WORDTAG O LA\n',
#  '1 WORDTAG O splenectomized\n',
#  '1 WORDTAG O Magnetically\n',
#  '12 WORDTAG I-GENE precursor\n',
#  '1 WORDTAG I-GENE thymic\n',
#  '1 WORDTAG I-GENE RelB\n',
#  '1 WORDTAG I-GENE 12Q229L\n',
#  '4 WORDTAG O Thrombosis\n',
#  '4 WORDTAG O consideration\n',
#  '1 WORDTAG O David\n',
#  '1 WORDTAG O Multilayer\n',
#  '1 WORDTAG O E768D\n',
#  '3 WORDTAG O duodenum\n',
#  '11 WORDTAG O suffering\n',
#  '1 WORDTAG O flaviviruses\n',
#  '1 WORDTAG O internalizes\n',
#  '1 WORDTAG I-GENE MafB\n',
#  '1 WORDTAG O constructions\n',
#  '1 WORDTAG O basically\n',
#  '26 WORDTAG O rabbits\n',
#  '1 WORDTAG O Immunophenotyping\n',
#  '1 WORDTAG O England\n',
#  '2 WORDTAG O -/\n',
#  '1 WORDTAG O aids\n',
#  '71 WORDTAG O specifically\n',
#  '1 WORDTAG O Delineating\n',
#  '8 WORDTAG O instrument\n',
#  '3 WORDTAG O ISO\n',
#  '1 WORDTAG I-GENE FP\n',
#  '6 WORDTAG O Chr\n',
#  '1 WORDTAG O Alcohol\n',
#  '1 WORDTAG O demyelinating\n',
#  '4 WORDTAG O percutaneous\n',
#  '1 WORDTAG O Micro\n',
#  '3 WORDTAG O immunogenic\n',
#  '1 WORDTAG I-GENE PTPases\n',
#  '1 WORDTAG O Purtilo\n',
#  '2 WORDTAG I-GENE TFIIH\n',
#  '1 WORDTAG O Houston\n',
#  '1 WORDTAG O hyperosmolality\n',
#  '1 WORDTAG I-GENE clover\n',
#  '1 WORDTAG O urographic\n',
#  '1 WORDTAG I-GENE MucA\n',
#  '1 WORDTAG I-GENE FkbC\n',
#  '2 WORDTAG I-GENE CRP2\n',
#  '1 WORDTAG I-GENE kappaB2\n',
#  '1 WORDTAG O RNL\n',
#  '1 WORDTAG I-GENE Sal1\n',
#  '1 WORDTAG O HPF\n',
#  '6 WORDTAG O eosinophils\n',
#  '1 WORDTAG O methoxyisobutylisonitrile\n',
#  '1 WORDTAG O 476\n',
#  '1 WORDTAG O Vo2DIR\n',
#  '2 WORDTAG O toxemia\n',
#  '1 WORDTAG O Periplaneta\n',
#  '4 WORDTAG I-GENE HB\n',
#  '49 WORDTAG O adjacent\n',
#  '1 WORDTAG O distorted\n',
#  '2 WORDTAG O 1228\n',
#  '1 WORDTAG O Tele\n',
#  '2 WORDTAG O security\n',
#  '1 WORDTAG I-GENE P5\n',
#  '10 WORDTAG I-GENE isoform\n',
#  '1 WORDTAG I-GENE cot\n',
#  '2 WORDTAG O violence\n',
#  '1 WORDTAG O Patho\n',
#  '1 WORDTAG O polyproteins\n',
#  '1 WORDTAG I-GENE lentil\n',
#  '871 WORDTAG O 5\n',
#  '2 WORDTAG O radiography\n',
#  '4 WORDTAG O bend\n',
#  '114 WORDTAG O concentration\n',
#  '1 WORDTAG O MBC\n',
#  '2 WORDTAG O Gulf\n',
#  '2 WORDTAG O C3\n',
#  '1 WORDTAG O arrangements\n',
#  '3 WORDTAG O scientific\n',
#  '1 WORDTAG O anovulent\n',
#  '1 WORDTAG O dissemination\n',
#  '1 WORDTAG O Cranio\n',
#  '4 WORDTAG O polyarteritis\n',
#  '36 WORDTAG O history\n',
#  '1 WORDTAG I-GENE MSH2\n',
#  '1 WORDTAG O excrete\n',
#  '1 WORDTAG I-GENE Tn5422\n',
#  '1 WORDTAG O nontetrahedral\n',
#  '2 WORDTAG O releases\n',
#  '2 WORDTAG O shed\n',
#  '4 WORDTAG O primitive\n',
#  '1 WORDTAG O SCD\n',
#  '1 WORDTAG O superconductor\n',
#  '1 WORDTAG O ALGO2\n',
#  '3 WORDTAG O 337\n',
#  '14 WORDTAG O thought\n',
#  '1 WORDTAG O trimethylsilylcarbamates\n',
#  '1 WORDTAG O EPD\n',
#  '1 WORDTAG O DNCB\n',
#  '2 WORDTAG O specify\n',
#  '2 WORDTAG O empirically\n',
#  '3 WORDTAG O seroconversion\n',
#  '1 WORDTAG O symport\n',
#  '1 WORDTAG I-GENE MLV\n',
#  '3 WORDTAG O surround\n',
#  '1 WORDTAG I-GENE CDR2\n',
#  '2 WORDTAG O Management\n',
#  '3 WORDTAG I-GENE SRC1\n',
#  '19 WORDTAG O abundant\n',
#  '1 WORDTAG O axl\n',
#  '3 WORDTAG O amplify\n',
#  '2 WORDTAG O EMS\n',
#  '16 WORDTAG O published\n',
#  '3 WORDTAG O Medical\n',
#  '1 WORDTAG O HPV16\n',
#  '1 WORDTAG O Targeted\n',
#  '3 WORDTAG O contributory\n',
#  '1 WORDTAG O SREs\n',
#  '1 WORDTAG O phenolic\n',
#  '11 WORDTAG I-GENE EPO\n',
#  '20 WORDTAG O Plasma\n',
#  '1 WORDTAG O Looming\n',
#  '6 WORDTAG O fungus\n',
#  '1 WORDTAG O Derepression\n',
#  '1 WORDTAG I-GENE VP22\n',
#  '1 WORDTAG O intophoresis\n',
#  '2 WORDTAG O salpingitis\n',
#  '2 WORDTAG I-GENE SmN\n',
#  '1 WORDTAG I-GENE naphthyl\n',
#  '4 WORDTAG O methacholine\n',
#  '1 WORDTAG I-GENE innercentrosome\n',
#  '1 WORDTAG O hydroxyindoleacetic\n',
#  '1 WORDTAG O B4\n',
#  '2 WORDTAG O comprehensive\n',
#  '6 WORDTAG O manifestation\n',
#  '5 WORDTAG O cardiomyopathy\n',
#  '3 WORDTAG O unacceptable\n',
#  '1 WORDTAG O Ontario\n',
#  '7 WORDTAG O links\n',
#  '2 WORDTAG I-GENE fructose\n',
#  '2 WORDTAG I-GENE Elk1\n',
#  '1 WORDTAG I-GENE Pet111p\n',
#  '1 WORDTAG O rye\n',
#  '1 WORDTAG O LOE\n',
#  '1 WORDTAG I-GENE verA\n',
#  '3 WORDTAG I-GENE Vbeta\n',
#  '2 WORDTAG O aneurysm\n',
#  '1 WORDTAG O Thr69\n',
#  '5 WORDTAG O antibiotics\n',
#  '1 WORDTAG I-GENE PfCPK\n',
#  '1 WORDTAG O chestnut\n',
#  '1 WORDTAG O Slowed\n',
#  '1 WORDTAG O nitrosoureas\n',
#  '2 WORDTAG O glycemic\n',
#  '1 WORDTAG O 314\n',
#  '1 WORDTAG O nephroma\n',
#  '5 WORDTAG O vibration\n',
#  '2 WORDTAG O Maternal\n',
#  '2 WORDTAG O nitric\n',
#  '1 WORDTAG O 99mtechnetium\n',
#  '1 WORDTAG I-GENE Kv4\n',
#  '3 WORDTAG O enabling\n',
#  '1 WORDTAG O ahead\n',
#  '2 WORDTAG O XII\n',
#  '3 WORDTAG O SPG\n',
#  '1 WORDTAG O fixative\n',
#  '1 WORDTAG O typ\n',
#  '2 WORDTAG I-GENE Ras2\n',
#  '4 WORDTAG I-GENE S4\n',
#  '2 WORDTAG O 4Fe\n',
#  '1 WORDTAG O STP\n',
#  '1 WORDTAG I-GENE srm1\n',
#  '2 WORDTAG O auricular\n',
#  '2 WORDTAG O irregularly\n',
#  '6 WORDTAG O synaptic\n',
#  '4 WORDTAG O chemiluminescence\n',
#  '5 WORDTAG I-GENE Cp\n',
#  '3 WORDTAG O PCDFs\n',
#  '1 WORDTAG O 1074\n',
#  '1 WORDTAG O crimped\n',
#  '2 WORDTAG O bsa\n',
#  '1 WORDTAG O OSAS\n',
#  '1 WORDTAG I-GENE alphaA\n',
#  '3 WORDTAG O depot\n',
#  '17 WORDTAG O dependence\n',
#  '1 WORDTAG O 940\n',
#  '1 WORDTAG I-GENE CarP\n',
#  '1 WORDTAG O phenol\n',
#  '1 WORDTAG O lysosomes\n',
#  '1 WORDTAG O videotapes\n',
#  '2 WORDTAG I-GENE Pho2\n',
#  '4 WORDTAG O EF\n',
#  '5 WORDTAG O tracer\n',
#  '46 WORDTAG O hours\n',
#  '1 WORDTAG I-GENE i2\n',
#  '1 WORDTAG I-GENE fliA\n',
#  '15 WORDTAG O heterodimer\n',
#  '29 WORDTAG O intensity\n',
#  '3 WORDTAG I-GENE polyomavirus\n',
#  '1 WORDTAG O inoperability\n',
#  '8 WORDTAG O antimicrobial\n',
#  '4 WORDTAG O defining\n',
#  '147 WORDTAG O residues\n',
#  '4 WORDTAG O SK\n',
#  '2 WORDTAG I-GENE alcR\n',
#  '4 WORDTAG O geometry\n',
#  '1 WORDTAG O works\n',
#  '47 WORDTAG O whose\n',
#  '1 WORDTAG O Word\n',
#  '1 WORDTAG O radiosensitivity\n',
#  '7 WORDTAG O successfully\n',
#  '2 WORDTAG O piglets\n',
#  '1 WORDTAG O exercised\n',
#  '1 WORDTAG O TaV\n',
#  '1 WORDTAG I-GENE cereus\n',
#  '2 WORDTAG I-GENE Pho85\n',
#  '1 WORDTAG I-GENE rlf2\n',
#  '113 WORDTAG O homology\n',
#  '1 WORDTAG O Referred\n',
#  '2 WORDTAG O neostigmine\n',
#  '3 WORDTAG O Statement\n',
#  '4 WORDTAG I-GENE HBe\n',
#  '4 WORDTAG O errors\n',
#  '2 WORDTAG I-GENE TFIIF\n',
#  '1 WORDTAG O indocyanine\n',
#  '1 WORDTAG O Intervention\n',
#  '11 WORDTAG I-GENE Bacillus\n',
#  '2 WORDTAG O screws\n',
#  '1 WORDTAG O immunopathology\n',
#  '1 WORDTAG O oestrus\n',
#  '4 WORDTAG O dyad\n',
#  '1 WORDTAG O protracted\n',
#  '1 WORDTAG O basidiocarp\n',
#  '2 WORDTAG O looked\n',
#  '8 WORDTAG O promoting\n',
#  '2 WORDTAG O flora\n',
#  '2 WORDTAG O TEE\n',
#  '1 WORDTAG O Transduction\n',
#  '5 WORDTAG O toe\n',
#  '1 WORDTAG O Fusion\n',
#  '2 WORDTAG O SHR\n',
#  '21 WORDTAG O alanine\n',
#  '2 WORDTAG O myoblast\n',
#  '1 WORDTAG O progresses\n',
#  '1 WORDTAG I-GENE C6\n',
#  '10 WORDTAG I-GENE mobility\n',
#  '1 WORDTAG O tricinctum\n',
#  '2 WORDTAG I-GENE exotoxin\n',
#  '4 WORDTAG I-GENE chemokine\n',
#  '1 WORDTAG O simulus\n',
#  '12 WORDTAG O cattle\n',
#  '2 WORDTAG O scatter\n',
#  '2 WORDTAG O cotransfections\n',
#  '9 WORDTAG O tip\n',
#  '1 WORDTAG I-GENE UL28\n',
#  '1 WORDTAG O acetic\n',
#  '4 WORDTAG O epidermal\n',
#  '1 WORDTAG I-GENE CAKs\n',
#  '1 WORDTAG O Visick\n',
#  '1 WORDTAG O meconium\n',
#  '3 WORDTAG O peptic\n',
#  '1 WORDTAG O boost\n',
#  '2 WORDTAG O disadvantages\n',
#  '2 WORDTAG I-GENE CiD\n',
#  '1 WORDTAG O arteriograms\n',
#  '1 WORDTAG O ravioli\n',
#  '2 WORDTAG I-GENE fungus\n',
#  '1 WORDTAG O UBE\n',
#  '1 WORDTAG O Cys181\n',
#  '1 WORDTAG O Pentium\n',
#  '1 WORDTAG I-GENE MiT\n',
#  '1 WORDTAG O wollastoni\n',
#  '2 WORDTAG O parity\n',
#  '18 WORDTAG O 89\n',
#  '1 WORDTAG O ingrowth\n',
#  '1 WORDTAG I-GENE destrin\n',
#  '3 WORDTAG O genera\n',
#  '2 WORDTAG O Serological\n',
#  '1 WORDTAG I-GENE ATX\n',
#  '1 WORDTAG I-GENE integrins\n',
#  '14 WORDTAG O 92\n',
#  '1 WORDTAG O generic\n',
#  '1 WORDTAG O TGTCCT\n',
#  '2 WORDTAG O CHR\n',
#  '2 WORDTAG O focally\n',
#  '1 WORDTAG I-GENE BCOD\n',
#  '2 WORDTAG O administering\n',
#  '5 WORDTAG O Resistance\n',
#  '1 WORDTAG O synchrotron\n',
#  '1 WORDTAG O italian\n',
#  '2 WORDTAG I-GENE Candida\n',
#  '1 WORDTAG O broadening\n',
#  '21 WORDTAG O unable\n',
#  '2 WORDTAG O powdered\n',
#  '1 WORDTAG I-GENE viperid\n',
#  '1 WORDTAG I-GENE Calpha\n',
#  '1 WORDTAG I-GENE GIN4\n',
#  '11 WORDTAG O circadian\n',
#  '1 WORDTAG O envious\n',
#  '1 WORDTAG O RE\n',
#  '3 WORDTAG I-GENE J\n',
#  '1 WORDTAG O Ghanaians\n',
#  '2 WORDTAG O H4PteGlun\n',
#  '3 WORDTAG O ?)\n',
#  '1 WORDTAG O chemoprevention\n',
#  '1 WORDTAG O Quantitation\n',
#  '1 WORDTAG O R7\n',
#  '1 WORDTAG O FSW\n',
#  '2 WORDTAG I-GENE atp6\n',
#  '6 WORDTAG I-GENE Cdk\n',
#  '2 WORDTAG O glial\n',
#  '1 WORDTAG I-GENE valosin\n',
#  '8 WORDTAG O Experimental\n',
#  '2 WORDTAG O Silastic\n',
#  '4 WORDTAG O intraperitoneal\n',
#  '6 WORDTAG O tetrofosmin\n',
#  '1 WORDTAG O HAL\n',
#  '1 WORDTAG I-GENE NGFB\n',
#  '1 WORDTAG O bloom\n',
#  '1 WORDTAG I-GENE CeGAP\n',
#  '1 WORDTAG O nicks\n',
#  '1 WORDTAG O endosomal\n',
#  '1 WORDTAG O prefabricated\n',
#  '1 WORDTAG O insects\n',
#  '19 WORDTAG O points\n',
#  '28 WORDTAG O step\n',
#  '1 WORDTAG O BDR\n',
#  '1 WORDTAG O digestibilities\n',
#  '2 WORDTAG O odor\n',
#  '2 WORDTAG O vertebra\n',
#  '1 WORDTAG O lay\n',
#  '1 WORDTAG I-GENE dsRBP\n',
#  '3 WORDTAG O reconstituting\n',
#  '1 WORDTAG I-GENE 73\n',
#  '153 WORDTAG O several\n',
#  '2 WORDTAG I-GENE FGFR1\n',
#  '2 WORDTAG O iridium\n',
#  '2 WORDTAG O ablate\n',
#  '6 WORDTAG O housekeeping\n',
#  '11 WORDTAG O leaves\n',
#  '1 WORDTAG O altitudes\n',
#  '1 WORDTAG I-GENE sulfurylase\n',
#  '1 WORDTAG O DPC\n',
#  '1 WORDTAG I-GENE YccA11\n',
#  '1 WORDTAG I-GENE 450e\n',
#  '1 WORDTAG O MC1061K\n',
#  '1 WORDTAG O CRTA\n',
#  '1 WORDTAG O RECs\n',
#  '1 WORDTAG I-GENE acetylhydrolase\n',
#  '1 WORDTAG O taps\n',
#  '1 WORDTAG O psychologic\n',
#  '1 WORDTAG O att\n',
#  '2 WORDTAG O Vitamin\n',
#  '1 WORDTAG O DIL\n',
#  '11 WORDTAG I-GENE thyroid\n',
#  '1 WORDTAG O Dermatology\n',
#  '1 WORDTAG O Allergan\n',
#  '1 WORDTAG O Phenotypic\n',
#  '1 WORDTAG O Coronal\n',
#  '10 WORDTAG O serves\n',
#  '5 WORDTAG I-GENE PA\n',
#  '1 WORDTAG O nP\n',
#  '1 WORDTAG I-GENE ApxII\n',
#  '1 WORDTAG O tethers\n',
#  '1 WORDTAG O Kondo\n',
#  '2 WORDTAG I-GENE Cdk7\n',
#  '7 WORDTAG O biphasic\n',
#  '7 WORDTAG O ARDS\n',
#  '1 WORDTAG I-GENE cpm7\n',
#  '19 WORDTAG O GTP\n',
#  '1 WORDTAG O +)/\n',
#  '2 WORDTAG O hygiene\n',
#  '1 WORDTAG O aurantifolia\n',
#  '46 WORDTAG O stable\n',
#  '96 WORDTAG O terminus\n',
#  '1 WORDTAG I-GENE Bm3P1\n',
#  '2 WORDTAG O RUB\n',
#  '1 WORDTAG O pesticide\n',
#  '1 WORDTAG I-GENE RBPJk\n',
#  '1 WORDTAG O RFSS\n',
#  '3 WORDTAG O dispersed\n',
#  '1 WORDTAG I-GENE Fp1\n',
#  '1 WORDTAG O CDDP\n',
#  '1 WORDTAG O feet\n',
#  '1 WORDTAG O ZN\n',
#  '1 WORDTAG O Cattaneo\n',
#  '4 WORDTAG O atracurium\n',
#  '5 WORDTAG O initiating\n',
#  '1 WORDTAG O pyrolyses\n',
#  '1 WORDTAG I-GENE UBC2\n',
#  '1 WORDTAG O retrospect\n',
#  '2 WORDTAG I-GENE p59v\n',
#  '4 WORDTAG O Seven\n',
#  '1 WORDTAG I-GENE Tyk2\n',
#  '1 WORDTAG O MDI\n',
#  '1 WORDTAG O elaborated\n',
#  '1 WORDTAG O colonoscopic\n',
#  '4 WORDTAG O lasted\n',
#  '1 WORDTAG O octadecyl\n',
#  '1 WORDTAG I-GENE AdpA\n',
#  '1 WORDTAG O radionuclides\n',
#  '1 WORDTAG I-GENE rad9\n',
#  '1 WORDTAG O GHM\n',
#  '1 WORDTAG O buphthalmos\n',
#  '2 WORDTAG O debt\n',
#  '1 WORDTAG O angles\n',
#  '1 WORDTAG O 3b\n',
#  '2 WORDTAG O Fragments\n',
#  '1 WORDTAG O presequences\n',
#  '1 WORDTAG I-GENE HFD\n',
#  '1 WORDTAG O respects\n',
#  '1 WORDTAG I-GENE pBLCAT2\n',
#  '1 WORDTAG O crowned\n',
#  '1 WORDTAG O goes\n',
#  '1 WORDTAG I-GENE yop\n',
#  '1 WORDTAG O Aymara\n',
#  '6 WORDTAG I-GENE FN\n',
#  '1 WORDTAG O matruchotii\n',
#  '3 WORDTAG O endocytosis\n',
#  '1 WORDTAG I-GENE mottle\n',
#  '1 WORDTAG O neuroectoderm\n',
#  '1 WORDTAG O SLOWPOKE\n',
#  '2 WORDTAG I-GENE Fission\n',
#  '1 WORDTAG O deciding\n',
#  '7 WORDTAG O serologic\n',
#  '1 WORDTAG O Hepatocellular\n',
#  '8 WORDTAG O inoculated\n',
#  '1 WORDTAG I-GENE PCPH\n',
#  '1 WORDTAG I-GENE alternatively\n',
#  '2 WORDTAG O remodeled\n',
#  '2 WORDTAG O restitution\n',
#  '3 WORDTAG I-GENE PrB\n',
#  '1 WORDTAG O Pharmacoeconomic\n',
#  '1 WORDTAG O convulsive\n',
#  '1 WORDTAG O VRG\n',
#  '1 WORDTAG O Hagen\n',
#  '2 WORDTAG O translucent\n',
#  '1 WORDTAG O Withdrawal\n',
#  '1 WORDTAG I-GENE THZif\n',
#  '23 WORDTAG O homolog\n',
#  '2 WORDTAG I-GENE p27Kip1\n',
#  '3 WORDTAG O photosensitized\n',
#  '1 WORDTAG O 382\n',
#  '3 WORDTAG O Cognitive\n',
#  '1 WORDTAG O tt\n',
#  '1 WORDTAG I-GENE hyperimmune\n',
#  '1 WORDTAG O favoring\n',
#  '1 WORDTAG O mercuric\n',
#  '1 WORDTAG O Dermal\n',
#  '5 WORDTAG O PT\n',
#  '1 WORDTAG O Confirming\n',
#  '2 WORDTAG I-GENE mdr2\n',
#  '8043 WORDTAG O in\n',
#  '9 WORDTAG O dissection\n',
#  '1 WORDTAG O motivation\n',
#  '9 WORDTAG O re\n',
#  '1 WORDTAG O Brevibacterium\n',
#  '7 WORDTAG O State\n',
#  '1 WORDTAG I-GENE dioxin\n',
#  '1 WORDTAG O Ham\n',
#  '1 WORDTAG O pZipNeo\n',
#  '1 WORDTAG I-GENE hBMAL1\n',
#  '1 WORDTAG O transdetermination\n',
#  '1 WORDTAG O homidum\n',
#  '2 WORDTAG O Pap\n',
#  '12 WORDTAG O orally\n',
#  '2 WORDTAG O EMBL3\n',
#  '1 WORDTAG I-GENE Rad3\n',
#  '2 WORDTAG O tolerable\n',
#  '1 WORDTAG O diary\n',
#  '10 WORDTAG O generalized\n',
#  '32 WORDTAG I-GENE murine\n',
#  '9 WORDTAG O nifedipine\n',
#  '1 WORDTAG I-GENE Cln3\n',
#  '3 WORDTAG O phylogenetically\n',
#  '3 WORDTAG O hepatocyte\n',
#  '1 WORDTAG O Prisma\n',
#  '1 WORDTAG O Can\n',
#  '1 WORDTAG O hypothalamo\n',
#  '2 WORDTAG O Near\n',
#  '1 WORDTAG I-GENE Ids3\n',
#  '1 WORDTAG O cardioactive\n',
#  '1 WORDTAG I-GENE Rhotekin\n',
#  '1 WORDTAG O Swertia\n',
#  '85 WORDTAG O common\n',
#  '2 WORDTAG I-GENE IRA2\n',
#  '1 WORDTAG O transpire\n',
#  '6 WORDTAG O lactis\n',
#  '1 WORDTAG O preinjury\n',
#  '3 WORDTAG O transfusions\n',
#  '1 WORDTAG I-GENE alpha2A\n',
#  '1 WORDTAG O Agnogenic\n',
#  '1 WORDTAG I-GENE Tek\n',
#  '5 WORDTAG O 136\n',
#  '7 WORDTAG O season\n',
#  '1 WORDTAG O Immunogenicity\n',
#  '1 WORDTAG I-GENE Ini1\n',
#  '3 WORDTAG O Laser\n',
#  '9 WORDTAG I-GENE pRb\n',
#  '46 WORDTAG O subunits\n',
#  '1 WORDTAG O coal\n',
#  '1 WORDTAG O fMR\n',
#  '1 WORDTAG O asparagus\n',
#  '3 WORDTAG O supplement\n',
#  '1 WORDTAG O augments\n',
#  '1 WORDTAG O +].\n',
#  '2 WORDTAG O steep\n',
#  '3 WORDTAG I-GENE Jak2\n',
#  '1 WORDTAG O keep\n',
#  '1 WORDTAG O Diclofenac\n',
#  '4 WORDTAG O glycerol\n',
#  '2 WORDTAG O Distribution\n',
#  '1 WORDTAG I-GENE PBSX\n',
#  '20 WORDTAG O affecting\n',
#  '1 WORDTAG I-GENE por\n',
#  '1 WORDTAG O Rhizopus\n',
#  '6 WORDTAG O transfections\n',
#  '1 WORDTAG O Personality\n',
#  '1 WORDTAG O engineering\n',
#  '1 WORDTAG O CLZ\n',
#  '1 WORDTAG I-GENE microphthalmia\n',
#  '4 WORDTAG O remain\n',
#  '1 WORDTAG O Competitionsupershift\n',
#  '1 WORDTAG O Irradiation\n',
#  '2 WORDTAG O practitioner\n',
#  '11 WORDTAG I-GENE abl\n',
#  '1 WORDTAG I-GENE HuEpo\n',
#  '1 WORDTAG O resumption\n',
#  '2 WORDTAG I-GENE ZNF74\n',
#  '1 WORDTAG O Alouatta\n',
#  '2 WORDTAG O transmit\n',
#  '1 WORDTAG O BLLs\n',
#  '1 WORDTAG O Moynihan\n',
#  '1 WORDTAG I-GENE fdp1\n',
#  '1 WORDTAG O Svensson\n',
#  '17 WORDTAG O /-\n',
#  '7 WORDTAG O contralateral\n',
#  '1 WORDTAG O Interference\n',
#  '1 WORDTAG O aerial\n',
#  '1 WORDTAG O avirulence\n',
#  '1 WORDTAG O QL\n',
#  '4 WORDTAG I-GENE laevis\n',
#  '1 WORDTAG O FDBA\n',
#  '3 WORDTAG O myristylation\n',
#  '5485 WORDTAG O a\n',
#  '1 WORDTAG O Redmond\n',
#  '1 WORDTAG I-GENE LAI\n',
#  '1 WORDTAG I-GENE Mov\n',
#  '41 WORDTAG O origin\n',
#  '1 WORDTAG O Interdomain\n',
#  '2 WORDTAG O trichome\n',
#  '1 WORDTAG O MTF\n',
#  '1 WORDTAG O milkfish\n',
#  '6 WORDTAG O HMPAO\n',
#  '2 WORDTAG O desaturation\n',
#  '1 WORDTAG O 985\n',
#  '2 WORDTAG O Glucocorticoid\n',
#  '2 WORDTAG O H4IIE\n',
#  '1 WORDTAG I-GENE Pan\n',
#  '7 WORDTAG O purification\n',
#  '2 WORDTAG I-GENE NC\n',
#  '1 WORDTAG O CEA\n',
#  '1 WORDTAG O S28\n',
#  '20 WORDTAG O Ca2\n',
#  '1 WORDTAG O Rev\n',
#  '1 WORDTAG O Chronotherapeutics\n',
#  '1 WORDTAG O stunning\n',
#  '5 WORDTAG O atropine\n',
#  '2 WORDTAG I-GENE FDP\n',
#  '4 WORDTAG I-GENE ALT\n',
#  '3 WORDTAG O 35S\n',
#  '1 WORDTAG O ureterosigmoidostomy\n',
#  '1 WORDTAG O 0625\n',
#  '450 WORDTAG O levels\n',
#  '1 WORDTAG O arteriopathies\n',
#  '1 WORDTAG I-GENE GAL7\n',
#  '1 WORDTAG I-GENE fingers\n',
#  '17 WORDTAG O numbers\n',
#  '2 WORDTAG I-GENE IRI\n',
#  '1 WORDTAG O PaGIA\n',
#  '10 WORDTAG O ingestion\n',
#  '1 WORDTAG O 10000\n',
#  '1 WORDTAG O inequalities\n',
#  '41 WORDTAG O assessed\n',
#  '1 WORDTAG I-GENE hSMT3b\n',
#  '3 WORDTAG O 267\n',
#  '1 WORDTAG O doing\n',
#  '1 WORDTAG O Scales\n',
#  '4 WORDTAG O Ro\n',
#  '2 WORDTAG O claudication\n',
#  '1 WORDTAG O claim\n',
#  '792 WORDTAG O activity\n',
#  '7 WORDTAG O adapted\n',
#  '1 WORDTAG O relinquishing\n',
#  '1 WORDTAG O Echinostomiasis\n',
#  '1 WORDTAG O MFH\n',
#  '1 WORDTAG O pyrido\n',
#  '1 WORDTAG O CRBPIIp\n',
#  '5 WORDTAG O branchpoint\n',
#  '2 WORDTAG O Bullous\n',
#  '1 WORDTAG O Broviac\n',
#  '1 WORDTAG I-GENE C2C\n',
#  '1 WORDTAG O microsequenced\n',
#  '3 WORDTAG O reticuloendothelial\n',
#  '1 WORDTAG O otology\n',
#  '1 WORDTAG O schizonts\n',
#  '3 WORDTAG O ISIS\n',
#  '1 WORDTAG O sterilely\n',
#  '1 WORDTAG I-GENE Defensins\n',
#  '7 WORDTAG O psychiatric\n',
#  '1 WORDTAG O succeeded\n',
#  '1 WORDTAG I-GENE E2R\n',
#  '2 WORDTAG I-GENE kinesin\n',
#  '17 WORDTAG O Isolation\n',
#  '1 WORDTAG I-GENE Lyp\n',
#  '23 WORDTAG O positively\n',
#  '1 WORDTAG O Gonzalez\n',
#  '6 WORDTAG O ADR\n',
#  '1 WORDTAG I-GENE special\n',
#  '1 WORDTAG I-GENE Atr\n',
#  '8 WORDTAG O US\n',
#  '1 WORDTAG O Her\n',
#  '1 WORDTAG O sufentanil\n',
#  '1 WORDTAG I-GENE Pax2\n',
#  '2 WORDTAG O justified\n',
#  '1 WORDTAG O Salmo\n',
#  '1 WORDTAG O anthropogenic\n',
#  '1 WORDTAG O Interactive\n',
#  '2 WORDTAG O haematocrit\n',
#  '4 WORDTAG O dosages\n',
#  '3 WORDTAG I-GENE cdc28\n',
#  '4 WORDTAG O variance\n',
#  '1 WORDTAG O ARIMIDEX\n',
#  '1 WORDTAG O searches\n',
#  '1 WORDTAG I-GENE Trdpm1\n',
#  '1 WORDTAG O Output\n',
#  '4 WORDTAG O striatal\n',
#  '1 WORDTAG O sulfanilamide\n',
#  '1 WORDTAG O interquartile\n',
#  '9 WORDTAG O localize\n',
#  '1 WORDTAG O Mucosal\n',
#  '10 WORDTAG O overlap\n',
#  '1 WORDTAG O abrogates\n',
#  '16 WORDTAG O 71\n',
#  '5 WORDTAG O floor\n',
#  '2 WORDTAG O epidermolysis\n',
#  '3 WORDTAG I-GENE ORFII\n',
#  '1 WORDTAG O 964\n',
#  '1 WORDTAG I-GENE LIMK1\n',
#  '2 WORDTAG I-GENE Sam68\n',
#  '1 WORDTAG I-GENE mtr\n',
#  '4 WORDTAG I-GENE 25\n',
#  '3 WORDTAG O drawn\n',
#  '1 WORDTAG O Let\n',
#  '1 WORDTAG O OCS\n',
#  '1 WORDTAG I-GENE Acra\n',
#  '4 WORDTAG O minimally\n',
#  '37 WORDTAG O infants\n',
#  '1 WORDTAG O MGDET\n',
#  '1 WORDTAG I-GENE Ubi1\n',
#  '3 WORDTAG O E26\n',
#  '2 WORDTAG O videotaped\n',
#  '4 WORDTAG O 179\n',
#  '1 WORDTAG O Rabi\n',
#  '8 WORDTAG O making\n',
#  '2 WORDTAG I-GENE SulA\n',
#  '7 WORDTAG I-GENE Rep\n',
#  '125 WORDTAG O signal\n',
#  '1 WORDTAG O armed\n',
#  '1 WORDTAG I-GENE contactin\n',
#  '16 WORDTAG O proportion\n',
#  '120 WORDTAG I-GENE NF\n',
#  '3 WORDTAG O bronchi\n',
#  '1 WORDTAG I-GENE GABAB\n',
#  '1 WORDTAG O Bronchial\n',
#  '1 WORDTAG I-GENE Mef\n',
#  '1 WORDTAG O PMMA\n',
#  '3 WORDTAG O T8\n',
#  '1 WORDTAG O endodontics\n',
#  '1 WORDTAG O Y594F\n',
#  '2 WORDTAG O dF\n',
#  '3 WORDTAG O Canadian\n',
#  '3 WORDTAG O mucoid\n',
#  '3 WORDTAG O adenoviral\n',
#  '1 WORDTAG O 1042\n',
#  '1 WORDTAG O casting\n',
#  '56 WORDTAG O segment\n',
#  '1 WORDTAG O netilmicin\n',
#  '1 WORDTAG O Cefaclor\n',
#  '1 WORDTAG I-GENE HNF3beta\n',
#  '16 WORDTAG O agreement\n',
#  '3 WORDTAG O inspection\n',
#  '29 WORDTAG O regulating\n',
#  '1 WORDTAG O Unaided\n',
#  '11 WORDTAG O roots\n',
#  '1 WORDTAG O CeCAT\n',
#  '4 WORDTAG O breakdown\n',
#  '146 WORDTAG O could\n',
#  '1 WORDTAG O perpetrators\n',
#  '1 WORDTAG O LH\n',
#  '1 WORDTAG O kdeg\n',
#  '8 WORDTAG I-GENE IRS\n',
#  '1 WORDTAG O T16\n',
#  '1 WORDTAG O electromyographically\n',
#  '1 WORDTAG O Hvan\n',
#  '1 WORDTAG O Valproate\n',
#  '1 WORDTAG O Greek\n',
#  '1 WORDTAG O PBK\n',
#  '1 WORDTAG O REVASC\n',
#  '1 WORDTAG O Lagos\n',
#  '1 WORDTAG I-GENE EUS4\n',
#  '4 WORDTAG O away\n',
#  '13 WORDTAG O Similar\n',
#  '5 WORDTAG I-GENE HIS3\n',
#  '4 WORDTAG O comigrated\n',
#  '1 WORDTAG O naltrindole\n',
#  '4 WORDTAG O JTc\n',
#  '1 WORDTAG I-GENE GCD7\n',
#  '4 WORDTAG O bis\n',
#  '1 WORDTAG O orchiectomised\n',
#  '2 WORDTAG O provoking\n',
#  '1 WORDTAG O 3x\n',
#  '1 WORDTAG O moods\n',
#  '1 WORDTAG O dn\n',
#  '1 WORDTAG O KEFGK\n',
#  '4 WORDTAG O integrate\n',
#  '2 WORDTAG O GMBF\n',
#  '1 WORDTAG O stolonifer\n',
#  '5 WORDTAG I-GENE ]\n',
#  '1 WORDTAG O agranulocytosis\n',
#  '1 WORDTAG O abundances\n',
#  '32 WORDTAG O subsequent\n',
#  '1 WORDTAG O orofacial\n',
#  '3 WORDTAG I-GENE Dd\n',
#  '1 WORDTAG O neurocan\n',
#  '77 WORDTAG O O2\n',
#  '4 WORDTAG O Ag\n',
#  '3 WORDTAG I-GENE bacteriophage\n',
#  '2 WORDTAG I-GENE cdc18\n',
#  '54 WORDTAG O additional\n',
#  '2 WORDTAG O CBZ\n',
#  '4 WORDTAG O fibrinolysis\n',
#  '1 WORDTAG O presentations\n',
#  '1 WORDTAG I-GENE Calmodulin\n',
#  '4 WORDTAG O vasculature\n',
#  '16 WORDTAG I-GENE 7\n',
#  '1 WORDTAG O Anisotropic\n',
#  '2 WORDTAG O orthoclone\n',
#  '5 WORDTAG O preterm\n',
#  '1 WORDTAG O curable\n',
#  '3 WORDTAG O deleterious\n',
#  '51 WORDTAG O useful\n',
#  '5 WORDTAG O shunt\n',
#  '1 WORDTAG O rachischisis\n',
#  '2 WORDTAG O 7q11\n',
#  '1 WORDTAG O hooks\n',
#  '164 WORDTAG O mRNA\n',
#  '1 WORDTAG I-GENE Smarcal1\n',
#  '3 WORDTAG O 32D\n',
#  '13 WORDTAG O modulation\n',
#  '16 WORDTAG O problem\n',
#  '1 WORDTAG I-GENE PNRC\n',
#  '1 WORDTAG O nGRE\n',
#  '1 WORDTAG O 26Mg\n',
#  '1 WORDTAG O mossy\n',
#  '2 WORDTAG O ventilators\n',
#  '1 WORDTAG O trimers\n',
#  '3 WORDTAG O Ab\n',
#  '1 WORDTAG I-GENE Uso1p\n',
#  '2 WORDTAG I-GENE fluid\n',
#  '6 WORDTAG O allelic\n',
#  '1 WORDTAG O Discordance\n',
#  '7 WORDTAG O chamber\n',
#  '1 WORDTAG O cardiotoxicity\n',
#  '5 WORDTAG O subcloned\n',
#  '3 WORDTAG O endometriosis\n',
#  '1 WORDTAG I-GENE Y88S\n',
#  '13 WORDTAG I-GENE consensus\n',
#  '1 WORDTAG O immunomodulatory\n',
#  '1 WORDTAG O SF2149\n',
#  '2 WORDTAG O Prazosin\n',
#  '3 WORDTAG O lumen\n',
#  '4 WORDTAG O facilitates\n',
#  '3 WORDTAG I-GENE hTAF\n',
#  '1 WORDTAG O ectatic\n',
#  '1 WORDTAG O gastro\n',
#  '1 WORDTAG O exciton\n',
#  '1 WORDTAG O curls\n',
#  '1 WORDTAG I-GENE Srf\n',
#  '1 WORDTAG O tobamo\n',
#  '1 WORDTAG I-GENE CIIB\n',
#  '2 WORDTAG I-GENE runt\n',
#  '2 WORDTAG I-GENE Bcr\n',
#  '26 WORDTAG O Treatment\n',
#  '2 WORDTAG O 477\n',
#  '1 WORDTAG O acceptors\n',
#  '5 WORDTAG O Chemical\n',
#  '1 WORDTAG I-GENE MFA2\n',
#  '1 WORDTAG I-GENE JunB\n',
#  '1 WORDTAG O calories\n',
#  '1 WORDTAG O autoregressive\n',
#  '14 WORDTAG O mitosis\n',
#  "1 WORDTAG I-GENE ')\n",
#  '1 WORDTAG I-GENE counterpart\n',
#  '1 WORDTAG I-GENE MCL1\n',
#  '1 WORDTAG O Aviators\n',
#  '2 WORDTAG I-GENE 68\n',
#  '1 WORDTAG O calculus\n',
#  '1 WORDTAG O 516\n',
#  '1 WORDTAG O Perfusion\n',
#  '7 WORDTAG O babies\n',
#  '1 WORDTAG O interior\n',
#  '1 WORDTAG O stabilising\n',
#  '1 WORDTAG O 2F5\n',
#  '1 WORDTAG O accreditation\n',
#  '1 WORDTAG I-GENE Aspergillus\n',
#  '1 WORDTAG I-GENE Pph21p\n',
#  '1 WORDTAG O jumping\n',
#  '1 WORDTAG I-GENE pT7\n',
#  '4 WORDTAG O complaints\n',
#  '58 WORDTAG O peripheral\n',
#  '2 WORDTAG O crest\n',
#  '1 WORDTAG O fading\n',
#  '3 WORDTAG O intraoperative\n',
#  '4 WORDTAG O epitopes\n',
#  '1 WORDTAG O intralesional\n',
#  '1 WORDTAG O pinhole\n',
#  '1 WORDTAG O Bordetella\n',
#  '1 WORDTAG O synaptosomal\n',
#  '1 WORDTAG O 3p21\n',
#  '7 WORDTAG I-GENE transfer\n',
#  '1 WORDTAG O Udry\n',
#  '2 WORDTAG O metaplasia\n',
#  '1 WORDTAG O BBScV\n',
#  '1 WORDTAG I-GENE cstA\n',
#  '1 WORDTAG O Fricker\n',
#  '1 WORDTAG O Necrosis\n',
#  '1 WORDTAG O Carausius\n',
#  '2 WORDTAG O discrepancies\n',
#  '35 WORDTAG O c\n',
#  '2 WORDTAG O 331\n',
#  '34 WORDTAG O maximal\n',
#  '2 WORDTAG O maxicell\n',
#  '1 WORDTAG O otorhinolaryngologic\n',
#  '1 WORDTAG O permeation\n',
#  '2 WORDTAG O GenBank\n',
#  '2 WORDTAG O Secretion\n',
#  '1 WORDTAG O plexiform\n',
#  '156 WORDTAG O either\n',
#  '1 WORDTAG I-GENE Bp50\n',
#  '1 WORDTAG O antisperm\n',
#  '1 WORDTAG I-GENE Rep52\n',
#  '3 WORDTAG I-GENE TyrTS\n',
#  '1 WORDTAG O spermicide\n',
#  '2 WORDTAG O detachment\n',
#  '11 WORDTAG O timing\n',
#  '2 WORDTAG O amniocentesis\n',
#  '7 WORDTAG I-GENE rheumatoid\n',
#  '3 WORDTAG O attack\n',
#  '1 WORDTAG O acanthocephalan\n',
#  '3 WORDTAG O imperfect\n',
#  '3 WORDTAG O Correlation\n',
#  '13 WORDTAG I-GENE repeat\n',
#  '2 WORDTAG O 910\n',
#  '1 WORDTAG I-GENE CYP3A23\n',
#  '3 WORDTAG I-GENE p85alpha\n',
#  '1 WORDTAG O decalcify\n',
#  '1 WORDTAG I-GENE KAP3\n',
#  '1 WORDTAG O phytomitogen\n',
#  '3 WORDTAG O vacuum\n',
#  ...]

# %%
p = defaultdict(lambda: defaultdict(int))

for line in lines:
    count, _, tag, token = line.split()
    p[token][tag] = int(count) / float(counts[tag])
